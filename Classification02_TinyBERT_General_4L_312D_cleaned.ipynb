# %%
# !pip install -U transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.55.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.34.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.21.4)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.14.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.1.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.8.3)

# %% [markdown]
# ## Local Inference on GPU
# Model page: https://huggingface.co/huawei-noah/TinyBERT_General_4L_312D
#
# ⚠️ If the generated code snippets do not work, please open an issue on either the [model repo](https://huggingface.co/huawei-noah/TinyBERT_General_4L_312D)
# 			and/or on [huggingface.js](https://github.com/huggingface/huggingface.js/blob/main/packages/tasks/src/model-libraries-snippets.ts) 🙏

# %%
# Load model directly
from transformers import AutoModel
model = AutoModel.from_pretrained("huawei-noah/TinyBERT_General_4L_312D", torch_dtype="auto"),
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/409 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/62.7M [00:00<?, ?B/s]

# %%
import pandas as pd

df0 = pd.read_parquet("hf://datasets/sdiazlor/text-classification-news-topics/generate_text_classification_data_0/train-00000-of-00001.parquet")
df1 = pd.read_parquet("hf://datasets/sdiazlor/text-classification-news-topics/generate_text_classification_data_1/train-00000-of-00001.parquet")
df2 = pd.read_parquet("hf://datasets/sdiazlor/text-classification-news-topics/generate_text_classification_data_2/train-00000-of-00001.parquet")

df = pd.concat([df0, df1, df2], ignore_index=True)
# Out:
# model.safetensors:   0%|          | 0.00/62.7M [00:00<?, ?B/s]

# %%
df.head()
# Out:
#                                              task  \
# 0  Determine the news article as sports, business
# 1  Determine the news article as sports, business
# 2  Determine the news article as sports, business
# 3  Determine the news article as sports, business
# 4  Determine the news article as sports, business
#
#                                           input_text     label  \
# 0  The recent surge in cryptocurrency prices has ...  business
# 1  The recent surge in the price of crude oil has...  business
# 2  The recent surge in cryptocurrency prices has ...  business
# 3  The New York Knicks' struggles on the court ha...  business
# 4  The New York Knicks' recent acquisition of sta...    sports
#
#   misleading_label                                distilabel_metadata  \
# 0           sports  {'raw_output_generate_text_classification_data...
# 1           sports  {'raw_output_generate_text_classification_data...
# 2           sports  {'raw_output_generate_text_classification_data...
# 3           sports  {'raw_output_generate_text_classification_data...
# 4         business  {'raw_output_generate_text_classification_data...
#
#                               model_name
# 0  meta-llama/Meta-Llama-3.1-8B-Instruct
# 1  meta-llama/Meta-Llama-3.1-8B-Instruct
# 2  meta-llama/Meta-Llama-3.1-8B-Instruct
# 3  meta-llama/Meta-Llama-3.1-8B-Instruct
# 4  meta-llama/Meta-Llama-3.1-8B-Instruct

# %%
df.isnull().sum()
# Out:
# task                   0
# input_text             3
# label                  3
# misleading_label       3
# distilabel_metadata    0
# model_name             0
# dtype: int64

# %%
df.dropna(subset=["input_text", "label"])
# Out:
#                                                    task  \
# 0        Determine the news article as sports, business
# 1        Determine the news article as sports, business
# 2        Determine the news article as sports, business
# 3        Determine the news article as sports, business
# 4        Determine the news article as sports, business
# ...                                                 ...
# 1195  Recognize the topic of the news article as Fac...
# 1196  Recognize the topic of the news article as Fac...
# 1197  Recognize the topic of the news article as Fac...
# 1198  Recognize the topic of the news article as Fac...
# 1199  Recognize the topic of the news article as Fac...
#
#                                              input_text          label  \
# 0     The recent surge in cryptocurrency prices has ...       business
# 1     The recent surge in the price of crude oil has...       business
# 2     The recent surge in cryptocurrency prices has ...       business
# 3     The New York Knicks' struggles on the court ha...       business
# 4     The New York Knicks' recent acquisition of sta...         sports
# ...                                                 ...            ...
# 1195  The recent study published in the Journal of E...     Fact-based
# 1196  The report by the World Health Organization su...     Fact-based
# 1197  The recent surge in global demand for renewabl...     Fact-based
# 1198  The recent study on the efficacy of renewable ...  Opinion-based
# 1199  The recent study on the effects of climate cha...     Fact-based
#
#      misleading_label                                distilabel_metadata  \
# 0              sports  {'raw_output_generate_text_classification_data...
# 1              sports  {'raw_output_generate_text_classification_data...
# 2              sports  {'raw_output_generate_text_classification_data...
# 3              sports  {'raw_output_generate_text_classification_data...
# 4            business  {'raw_output_generate_text_classification_data...
# ...               ...                                                ...
# 1195    Opinion-based  {'raw_output_generate_text_classification_data...
# 1196    Opinion-based  {'raw_output_generate_text_classification_data...
# 1197    Opinion-based  {'raw_output_generate_text_classification_data...
# 1198       Fact-based  {'raw_output_generate_text_classification_data...
# 1199    Opinion-based  {'raw_output_generate_text_classification_data...
#
#                                  model_name
# 0     meta-llama/Meta-Llama-3.1-8B-Instruct
# 1     meta-llama/Meta-Llama-3.1-8B-Instruct
# 2     meta-llama/Meta-Llama-3.1-8B-Instruct
# 3     meta-llama/Meta-Llama-3.1-8B-Instruct
# 4     meta-llama/Meta-Llama-3.1-8B-Instruct
# ...                                     ...
# 1195  meta-llama/Meta-Llama-3.1-8B-Instruct
# 1196  meta-llama/Meta-Llama-3.1-8B-Instruct
# 1197  meta-llama/Meta-Llama-3.1-8B-Instruct
# 1198  meta-llama/Meta-Llama-3.1-8B-Instruct
# 1199  meta-llama/Meta-Llama-3.1-8B-Instruct
#
# [1197 rows x 6 columns]

# %%
df.describe()
# Out:
#                                                   task  \
# count                                             1200
# unique                                              34
# top     Determine the news article as sports, business
# freq                                                60
#
#                                                input_text     label  \
# count                                                1197      1197
# unique                                               1193         9
# top     Researchers at the European Organization for N...  sci/tech
# freq                                                    2       383
#
#        misleading_label                                distilabel_metadata  \
# count              1197                                               1200
# unique                7                                               1200
# top              sports  {'raw_output_generate_text_classification_data...
# freq                373                                                  1
#
#                                    model_name
# count                                    1200
# unique                                      1
# top     meta-llama/Meta-Llama-3.1-8B-Instruct
# freq                                     1200

# %%
print(df["label"].value_counts())
# Out:
# label
# sci/tech              383
# business              267
# world                 193
# Fact-based            129
# Opinion-based         111
# sports                 76
# sci                    30
# Business                7
# science_technology      1
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df["label_id"] = le.fit_transform(df["label"])
label2id = dict(zip(le.classes_, le.transform(le.classes_)))
id2label = {v: k for k, v in label2id.items()}

# %%
df.head()
# Out:
#                                              task  \
# 0  Determine the news article as sports, business
# 1  Determine the news article as sports, business
# 2  Determine the news article as sports, business
# 3  Determine the news article as sports, business
# 4  Determine the news article as sports, business
#
#                                           input_text     label  \
# 0  The recent surge in cryptocurrency prices has ...  business
# 1  The recent surge in the price of crude oil has...  business
# 2  The recent surge in cryptocurrency prices has ...  business
# 3  The New York Knicks' struggles on the court ha...  business
# 4  The New York Knicks' recent acquisition of sta...    sports
#
#   misleading_label                                distilabel_metadata  \
# 0           sports  {'raw_output_generate_text_classification_data...
# 1           sports  {'raw_output_generate_text_classification_data...
# 2           sports  {'raw_output_generate_text_classification_data...
# 3           sports  {'raw_output_generate_text_classification_data...
# 4         business  {'raw_output_generate_text_classification_data...
#
#                               model_name  label_id
# 0  meta-llama/Meta-Llama-3.1-8B-Instruct         3
# 1  meta-llama/Meta-Llama-3.1-8B-Instruct         3
# 2  meta-llama/Meta-Llama-3.1-8B-Instruct         3
# 3  meta-llama/Meta-Llama-3.1-8B-Instruct         3
# 4  meta-llama/Meta-Llama-3.1-8B-Instruct         7

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("huawei-noah/TinyBERT_General_4L_312D")
# Out:
# vocab.txt: 0.00B [00:00, ?B/s]

# %%
from datasets import Dataset, Features, Value, ClassLabel
df["input_text"] = df["input_text"].astype(str)
df["label"] = df["label_id"]

features = Features({
    "input_text": Value("string"),
    "label": ClassLabel(num_classes=len(df["label"].unique()))
})

# %%
dataset = Dataset.from_pandas(df[["input_text", "label"]], features=features)

# %%
def tokenize_function(examples):
    return tokenizer(
        examples["input_text"],
        padding="max_length",
        truncation=True,
        max_length=256,
    )

tokenized_dataset = dataset.map(tokenize_function, batched=True)
# Out:
# Map:   0%|          | 0/1200 [00:00<?, ? examples/s]

# %%
from datasets import DatasetDict

split_dataset = tokenized_dataset.train_test_split(test_size=0.2)

from transformers import AutoModelForSequenceClassification, TrainingArguments, Trainer
import numpy as np

# %%
from transformers import AutoModelForSequenceClassification

model = AutoModelForSequenceClassification.from_pretrained(
    "huawei-noah/TinyBERT_General_4L_312D",
    num_labels=10
)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at huawei-noah/TinyBERT_General_4L_312D and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from sklearn.metrics import accuracy_score, precision_recall_fscore_support

def compute_metrics(pred):
    labels = pred.label_ids
    preds = pred.predictions.argmax(-1)

    acc = accuracy_score(labels, preds)
    precision, recall, f1, _ = precision_recall_fscore_support(labels, preds, average='weighted')

    return {
        'accuracy': acc,
        'precision': precision,
        'recall': recall,
        'f1': f1,
    }

# %%
 from transformers import Trainer, TrainingArguments

training_args = TrainingArguments(
    output_dir="./results",
    per_device_train_batch_size=16,
    num_train_epochs=3,
    learning_rate=2e-5,
    logging_steps=10,
    logging_dir="./logs",
    report_to="none"
)

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=split_dataset["train"],
    eval_dataset=split_dataset["test"],
    tokenizer=tokenizer,
    compute_metrics=compute_metrics
)

trainer.train()
# Out:
# /tmp/ipython-input-3145630117.py:1: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
#     <div>
#
#       <progress value='180' max='180' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [180/180 00:17, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>2.293900</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>2.244800</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>2.191800</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>2.159300</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>2.124700</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>2.093200</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>2.039200</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>2.026100</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>2.030500</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.972100</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>1.971100</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>1.915100</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>1.934500</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>1.879500</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>1.877400</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>1.916100</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>1.861000</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>1.841000</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=180, training_loss=2.020625220404731, metrics={'train_runtime': 18.7115, 'train_samples_per_second': 153.916, 'train_steps_per_second': 9.62, 'total_flos': 20659231457280.0, 'train_loss': 2.020625220404731, 'epoch': 3.0})

# %%
trainer.evaluate()
# Out:
#     <div>
#
#       <progress value='30' max='30' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [30/30 00:00]
#     </div>
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# {'eval_loss': 1.8621314764022827,
#  'eval_accuracy': 0.525,
#  'eval_precision': 0.33503959276018097,
#  'eval_recall': 0.525,
#  'eval_f1': 0.3983870967741936,
#  'eval_runtime': 0.5448,
#  'eval_samples_per_second': 440.522,
#  'eval_steps_per_second': 55.065,
#  'epoch': 3.0}

# %%
from sklearn.metrics import classification_report

preds_output = trainer.predict(split_dataset["test"])
preds = preds_output.predictions.argmax(-1)
labels = preds_output.label_ids

print(classification_report(labels, preds))
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0.00      0.00      0.00        24
#            2       0.00      0.00      0.00        18
#            3       0.33      0.90      0.48        50
#            4       0.00      0.00      0.00        11
#            5       0.78      0.99      0.87        82
#            6       0.00      0.00      0.00         1
#            7       0.00      0.00      0.00        18
#            8       0.00      0.00      0.00        34
#
#     accuracy                           0.53       240
#    macro avg       0.12      0.21      0.15       240
# weighted avg       0.34      0.53      0.40       240
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(labels, preds)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
import time

inputs = tokenizer("This is a test sentence for latency measurement.", return_tensors="pt").to(model.device)


_ = model(**inputs)

num_runs = 50
start_time = time.time()
for _ in range(num_runs):
    _ = model(**inputs)
end_time = time.time()

avg_latency = (end_time - start_time) / num_runs
print(f"Average inference latency: {avg_latency * 1000:.2f} ms")
# Out:
# Average inference latency: 5.72 ms

# %%
import torch

torch.cuda.empty_cache()
torch.cuda.reset_peak_memory_stats()

_ = model(**inputs)

current_mem = torch.cuda.memory_allocated() / 1024**2
peak_mem = torch.cuda.max_memory_allocated() / 1024**2

print(f"Current GPU memory allocated: {current_mem:.2f} MB")
print(f"Peak GPU memory allocated: {peak_mem:.2f} MB")
# Out:
# Current GPU memory allocated: 183.13 MB
# Peak GPU memory allocated: 185.09 MB

# %%
import os, psutil

process = psutil.Process(os.getpid())
print(f"Memory usage: {process.memory_info().rss / 1024**2:.2f} MB")
# Out:
# Memory usage: 2115.59 MB

# %%
for batch_size in [1, 8, 16, 32]:
    inputs = tokenizer(
        ["This is a test sentence."] * batch_size,
        return_tensors="pt",
        padding=True,
        truncation=True
    ).to(model.device)

    _ = model(**inputs)

    start = time.time()
    _ = model(**inputs)
    end = time.time()

    print(f"Batch size {batch_size} - Latency: {(end-start)*1000:.2f} ms")
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Batch size 1 - Latency: 5.27 ms
# Batch size 8 - Latency: 5.66 ms
# Batch size 16 - Latency: 5.99 ms
# Batch size 32 - Latency: 10.42 ms
